# %% [markdown]
# ## 퍼셉트론 1개를 이용한 오차역전파

# %%
import numpy as np

# (특성데이터, 라벨데이터, 반복수, 학습률)
def fit_user(X, y, epoch, lr):
    #(1) w,b를 랜덤으로 초기화
    w = np.random.rand(1)
    b = np.random.rand(1)
    
    # epoch 수만큼 반복
    for i in range(epoch) : 
        # (2) 특성 데이터를 입력해서 라벨 데이터를 예측
        pred_y = w * X + b
        
        #(3) 오차 계산 (실제값 - 예측값)
        e = y - pred_y
        
        #(4) 미분을 해서 기울기를 계산 (w,b가 e에 얼마나 영향을 주고 있는지 분석)
        dw = e / w
        db = e / b
        
        # (5) 경사를 이용해서 w,b를 갱신 
        # 학습률을 적용 - w,b가 너무 크게 변하는 것을 방지하기 위한 것
        w = w + dw * lr
        b = b + db * lr
        
        # 중간결과 출력
        print("반복수 : {}, 예측값 : {}, 오차:{}".format(i, pred_y, e))
        print("현재 파라미터 : -> w : {}, b : {}".format(w,b))

# %%
fit_user(1,3,100,0.01)
# Out:
# 반복수 : 0, 예측값 : [1.04806136], 오차:[1.95193864]
# 현재 파라미터 : -> w : [0.31852766], b : [0.83636969]
# 반복수 : 1, 예측값 : [1.15489735], 오차:[1.84510265]
# 현재 파라미터 : -> w : [0.37645364], b : [0.85843054]
# 반복수 : 2, 예측값 : [1.23488418], 오차:[1.76511582]
# 현재 파라미터 : -> w : [0.42334164], b : [0.87899267]
# 반복수 : 3, 예측값 : [1.30233431], 오차:[1.69766569]
# 현재 파라미터 : -> w : [0.46344319], b : [0.89830643]
# 반복수 : 4, 예측값 : [1.36174962], 오차:[1.63825038]
# 현재 파라미터 : -> w : [0.49879273], b : [0.91654353]
# 반복수 : 5, 예측값 : [1.41533626], 오차:[1.58466374]
# 현재 파라미터 : -> w : [0.53056272], b : [0.93383309]
# 반복수 : 6, 예측값 : [1.46439581], 오차:[1.53560419]
# 현재 파라미터 : -> w : [0.55950565], b : [0.95027719]
# 반복수 : 7, 예측값 : [1.50978284], 오차:[1.49021716]
# 현재 파라미터 : -> w : [0.58614018], b : [0.96595911]
# 반복수 : 8, 예측값 : [1.5520993], 오차:[1.4479007]
# 현재 파라미터 : -> w : [0.61084248], b : [0.98094837]
# 반복수 : 9, 예측값 : [1.59179084], 오차:[1.40820916]
# 현재 파라미터 : -> w : [0.63389603], b : [0.99530396]
# 반복수 : 10, 예측값 : [1.62919999], 오차:[1.37080001]
# 현재 파라미터 : -> w : [0.65552103], b : [1.00907663]
# 반복수 : 11, 예측값 : [1.66459766], 오차:[1.33540234]
# 현재 파라미터 : -> w : [0.67589265], b : [1.02231054]
# 반복수 : 12, 예측값 : [1.69820318], 오차:[1.30179682]
# 현재 파라미터 : -> w : [0.69515306], b : [1.03504441]
# 반복수 : 13, 예측값 : [1.73019746], 오차:[1.26980254]
# 현재 파라미터 : -> w : [0.71341957], b : [1.0473125]
# 반복수 : 14, 예측값 : [1.76073208], 오차:[1.23926792]
# 현재 파라미터 : -> w : [0.73079039], b : [1.05914534]
# 반복수 : 15, 예측값 : [1.78993573], 오차:[1.21006427]
# 현재 파라미터 : -> w : [0.74734868], b : [1.07057025]
# 반복수 : 16, 예측값 : [1.81791894], 오차:[1.18208106]
# 현재 파라미터 : -> w : [0.76316568], b : [1.08161186]
# 반복수 : 17, 예측값 : [1.84477753], 오차:[1.15522247]
# 현재 파라미터 : -> w : [0.77830292], b : [1.09229242]
# 반복수 : 18, 예측값 : [1.87059534], 오차:[1.12940466]
# 현재 파라미터 : -> w : [0.79281404], b : [1.10263218]
# 반복수 : 19, 예측값 : [1.89544623], 오차:[1.10455377]
# 현재 파라미터 : -> w : [0.80674611], b : [1.11264961]
# 반복수 : 20, 예측값 : [1.91939572], 오차:[1.08060428]
# 현재 파라미터 : -> w : [0.82014071], b : [1.1223616]
# 반복수 : 21, 예측값 : [1.94250231], 오차:[1.05749769]
# 현재 파라미터 : -> w : [0.83303481], b : [1.13178368]
# 반복수 : 22, 예측값 : [1.96481849], 오차:[1.03518151]
# 현재 파라미터 : -> w : [0.84546144], b : [1.14093014]
# 반복수 : 23, 예측값 : [1.98639158], 오차:[1.01360842]
# 현재 파라미터 : -> w : [0.85745026], b : [1.14981419]
# 반복수 : 24, 예측값 : [2.00726445], 오차:[0.99273555]
# 현재 파라미터 : -> w : [0.86902802], b : [1.15844807]
# 반복수 : 25, 예측값 : [2.02747609], 오차:[0.97252391]
# 현재 파라미터 : -> w : [0.88021896], b : [1.16684313]
# 반복수 : 26, 예측값 : [2.04706209], 오차:[0.95293791]
# 현재 파라미터 : -> w : [0.89104511], b : [1.17500993]
# 반복수 : 27, 예측값 : [2.06605504], 오차:[0.93394496]
# 현재 파라미터 : -> w : [0.90152656], b : [1.18295833]
# 반복수 : 28, 예측값 : [2.08448489], 오차:[0.91551511]
# 현재 파라미터 : -> w : [0.91168173], b : [1.19069753]
# 반복수 : 29, 예측값 : [2.10237926], 오차:[0.89762074]
# 현재 파라미터 : -> w : [0.92152749], b : [1.19823615]
# 반복수 : 30, 예측값 : [2.11976364], 오차:[0.88023636]
# 현재 파라미터 : -> w : [0.93107942], b : [1.20558225]
# 반복수 : 31, 예측값 : [2.13666167], 오차:[0.86333833]
# 현재 파라미터 : -> w : [0.94035187], b : [1.21274342]
# 반복수 : 32, 예측값 : [2.15309529], 오차:[0.84690471]
# 현재 파라미터 : -> w : [0.94935812], b : [1.2197268]
# 반복수 : 33, 예측값 : [2.16908492], 오차:[0.83091508]
# 현재 파라미터 : -> w : [0.95811051], b : [1.2265391]
# 반복수 : 34, 예측값 : [2.18464961], 오차:[0.81535039]
# 현재 파라미터 : -> w : [0.96662049], b : [1.23318667]
# 반복수 : 35, 예측값 : [2.19980717], 오차:[0.80019283]
# 현재 파라미터 : -> w : [0.97489874], b : [1.2396755]
# 반복수 : 36, 예측값 : [2.21457424], 오차:[0.78542576]
# 현재 파라미터 : -> w : [0.98295523], b : [1.24601123]
# 반복수 : 37, 예측값 : [2.22896646], 오차:[0.77103354]
# 현재 파라미터 : -> w : [0.99079926], b : [1.25219925]
# 반복수 : 38, 예측값 : [2.24299851], 오차:[0.75700149]
# 현재 파라미터 : -> w : [0.99843958], b : [1.25824462]
# 반복수 : 39, 예측값 : [2.2566842], 오차:[0.7433158]
# 현재 파라미터 : -> w : [1.00588435], b : [1.26415218]
# 반복수 : 40, 예측값 : [2.27003654], 오차:[0.72996346]
# 현재 파라미터 : -> w : [1.01314128], b : [1.26992652]
# 반복수 : 41, 예측값 : [2.2830678], 오차:[0.7169322]
# 현재 파라미터 : -> w : [1.02021761], b : [1.27557198]
# 반복수 : 42, 예측값 : [2.29578959], 오차:[0.70421041]
# 현재 파라미터 : -> w : [1.02712016], b : [1.28109272]
# 반복수 : 43, 예측값 : [2.30821289], 오차:[0.69178711]
# 현재 파라미터 : -> w : [1.03385538], b : [1.2864927]
# 반복수 : 44, 예측값 : [2.32034807], 오차:[0.67965193]
# 현재 파라미터 : -> w : [1.04042933], b : [1.29177568]
# 반복수 : 45, 예측값 : [2.33220501], 오차:[0.66779499]
# 현재 파라미터 : -> w : [1.04684779], b : [1.29694527]
# 반복수 : 46, 예측값 : [2.34379306], 오차:[0.65620694]
# 현재 파라미터 : -> w : [1.0531162], b : [1.30200491]
# 반복수 : 47, 예측값 : [2.3551211], 오차:[0.6448789]
# 현재 파라미터 : -> w : [1.05923973], b : [1.30695787]
# 반복수 : 48, 예측값 : [2.3661976], 오차:[0.6338024]
# 현재 파라미터 : -> w : [1.06522329], b : [1.31180732]
# 반복수 : 49, 예측값 : [2.37703061], 오차:[0.62296939]
# 현재 파라미터 : -> w : [1.07107154], b : [1.31655626]
# 반복수 : 50, 예측값 : [2.3876278], 오차:[0.6123722]
# 현재 파라미터 : -> w : [1.07678892], b : [1.32120758]
# 반복수 : 51, 예측값 : [2.3979965], 오차:[0.6020035]
# 현재 파라미터 : -> w : [1.08237965], b : [1.32576404]
# 반복수 : 52, 예측값 : [2.40814369], 오차:[0.59185631]
# 현재 파라미터 : -> w : [1.08784775], b : [1.33022831]
# 반복수 : 53, 예측값 : [2.41807606], 오차:[0.58192394]
# 현재 파라미터 : -> w : [1.09319706], b : [1.33460293]
# 반복수 : 54, 예측값 : [2.42779999], 오차:[0.57220001]
# 현재 파라미터 : -> w : [1.09843125], b : [1.33889034]
# 반복수 : 55, 예측값 : [2.4373216], 오차:[0.5626784]
# 현재 파라미터 : -> w : [1.10355381], b : [1.34309292]
# 반복수 : 56, 예측값 : [2.44664673], 오차:[0.55335327]
# 현재 파라미터 : -> w : [1.1085681], b : [1.34721291]
# 반복수 : 57, 예측값 : [2.45578101], 오차:[0.54421899]
# 현재 파라미터 : -> w : [1.11347731], b : [1.3512525]
# 반복수 : 58, 예측값 : [2.46472981], 오차:[0.53527019]
# 현재 파라미터 : -> w : [1.1182845], b : [1.35521379]
# 반복수 : 59, 예측값 : [2.47349829], 오차:[0.52650171]
# 현재 파라미터 : -> w : [1.12299262], b : [1.3590988]
# 반복수 : 60, 예측값 : [2.48209142], 오차:[0.51790858]
# 현재 파라미터 : -> w : [1.12760448], b : [1.36290947]
# 반복수 : 61, 예측값 : [2.49051396], 오차:[0.50948604]
# 현재 파라미터 : -> w : [1.13212279], b : [1.3666477]
# 반복수 : 62, 예측값 : [2.49877048], 오차:[0.50122952]
# 현재 파라미터 : -> w : [1.13655013], b : [1.37031528]
# 반복수 : 63, 예측값 : [2.50686541], 오차:[0.49313459]
# 현재 파라미터 : -> w : [1.140889], b : [1.37391398]
# 반복수 : 64, 예측값 : [2.51480298], 오차:[0.48519702]
# 현재 파라미터 : -> w : [1.1451418], b : [1.37744547]
# 반복수 : 65, 예측값 : [2.52258727], 오차:[0.47741273]
# 현재 파라미터 : -> w : [1.14931083], b : [1.3809114]
# 반복수 : 66, 예측값 : [2.53022223], 오차:[0.46977777]
# 현재 파라미터 : -> w : [1.1533983], b : [1.38431334]
# 반복수 : 67, 예측값 : [2.53771164], 오차:[0.46228836]
# 현재 파라미터 : -> w : [1.15740635], b : [1.38765282]
# 반복수 : 68, 예측값 : [2.54505917], 오차:[0.45494083]
# 현재 파라미터 : -> w : [1.16133705], b : [1.39093131]
# 반복수 : 69, 예측값 : [2.55226836], 오차:[0.44773164]
# 현재 파라미터 : -> w : [1.16519236], b : [1.39415024]
# 반복수 : 70, 예측값 : [2.5593426], 오차:[0.4406574]
# 현재 파라미터 : -> w : [1.1689742], b : [1.397311]
# 반복수 : 71, 예측값 : [2.5662852], 오차:[0.4337148]
# 현재 파라미터 : -> w : [1.17268442], b : [1.40041493]
# 반복수 : 72, 예측값 : [2.57309935], 오차:[0.42690065]
# 현재 파라미터 : -> w : [1.17632479], b : [1.40346332]
# 반복수 : 73, 예측값 : [2.5797881], 오차:[0.4202119]
# 현재 파라미터 : -> w : [1.17989703], b : [1.40645742]
# 반복수 : 74, 예측값 : [2.58635445], 오차:[0.41364555]
# 현재 파라미터 : -> w : [1.18340281], b : [1.40939847]
# 반복수 : 75, 예측값 : [2.59280128], 오차:[0.40719872]
# 현재 파라미터 : -> w : [1.18684372], b : [1.41228763]
# 반복수 : 76, 예측값 : [2.59913136], 오차:[0.40086864]
# 현재 파라미터 : -> w : [1.19022133], b : [1.41512607]
# 반복수 : 77, 예측값 : [2.60534739], 오차:[0.39465261]
# 현재 파라미터 : -> w : [1.19353712], b : [1.41791488]
# 반복수 : 78, 예측값 : [2.611452], 오차:[0.388548]
# 현재 파라미터 : -> w : [1.19679255], b : [1.42065516]
# 반복수 : 79, 예측값 : [2.61744771], 오차:[0.38255229]
# 현재 파라미터 : -> w : [1.19998903], b : [1.42334795]
# 반복수 : 80, 예측값 : [2.62333698], 오차:[0.37666302]
# 현재 파라미터 : -> w : [1.20312792], b : [1.42599427]
# 반복수 : 81, 예측값 : [2.62912218], 오차:[0.37087782]
# 현재 파라미터 : -> w : [1.20621053], b : [1.4285951]
# 반복수 : 82, 예측값 : [2.63480563], 오차:[0.36519437]
# 현재 파라미터 : -> w : [1.20923815], b : [1.43115142]
# 반복수 : 83, 예측값 : [2.64038957], 오차:[0.35961043]
# 현재 파라미터 : -> w : [1.21221201], b : [1.43366416]
# 반복수 : 84, 예측값 : [2.64587616], 오차:[0.35412384]
# 현재 파라미터 : -> w : [1.21513331], b : [1.43613422]
# 반복수 : 85, 예측값 : [2.65126753], 오차:[0.34873247]
# 현재 파라미터 : -> w : [1.21800322], b : [1.43856249]
# 반복수 : 86, 예측값 : [2.65656571], 오차:[0.34343429]
# 현재 파라미터 : -> w : [1.22082287], b : [1.44094983]
# 반복수 : 87, 예측값 : [2.66177271], 오차:[0.33822729]
# 현재 파라미터 : -> w : [1.22359336], b : [1.44329709]
# 반복수 : 88, 예측값 : [2.66689044], 오차:[0.33310956]
# 현재 파라미터 : -> w : [1.22631574], b : [1.44560506]
# 반복수 : 89, 예측값 : [2.67192081], 오차:[0.32807919]
# 현재 파라미터 : -> w : [1.22899107], b : [1.44787456]
# 반복수 : 90, 예측값 : [2.67686563], 오차:[0.32313437]
# 현재 파라미터 : -> w : [1.23162033], b : [1.45010634]
# 반복수 : 91, 예측값 : [2.68172668], 오차:[0.31827332]
# 현재 파라미터 : -> w : [1.23420452], b : [1.45230117]
# 반복수 : 92, 예측값 : [2.68650569], 오차:[0.31349431]
# 현재 파라미터 : -> w : [1.23674457], b : [1.45445977]
# 반복수 : 93, 예측값 : [2.69120434], 오차:[0.30879566]
# 현재 파라미터 : -> w : [1.23924141], b : [1.45658287]
# 반복수 : 94, 예측값 : [2.69582428], 오차:[0.30417572]
# 현재 파라미터 : -> w : [1.24169594], b : [1.45867115]
# 반복수 : 95, 예측값 : [2.70036709], 오차:[0.29963291]
# 현재 파라미터 : -> w : [1.24410904], b : [1.4607253]
# 반복수 : 96, 예측값 : [2.70483434], 오차:[0.29516566]
# 현재 파라미터 : -> w : [1.24648154], b : [1.46274598]
# 반복수 : 97, 예측값 : [2.70922752], 오차:[0.29077248]
# 현재 파라미터 : -> w : [1.24881429], b : [1.46473383]
# 반복수 : 98, 예측값 : [2.71354812], 오차:[0.28645188]
# 현재 파라미터 : -> w : [1.25110808], b : [1.46668949]
# 반복수 : 99, 예측값 : [2.71779757], 오차:[0.28220243]
# 현재 파라미터 : -> w : [1.2533637], b : [1.46861357]

# %% [markdown]
# ## 퍼셉트론 2개를 이용한 오차역전파

# %%
import numpy as np

# (특성 데이터, 라벨 데이터, 반복수, 학습률)
def fit_user2(X, y, epoch, lr):
    # (1) w, b를 랜덤으로 초기화
    w1=np.random.randn(1)
    b1=np.random.randn(1)
    w2=np.random.randn(1)
    b2=np.random.randn(1)
    
    # epoch 수만큼 반복
    for i in range(epoch) :
        # (2) 특성 데이터를 입력해서 라벨데이터를 예측
        # 1층 중간 결과
        pred_y1 = w1*X+b1
        # 2층의 결과
        pred_y2 = w2*pred_y1+b2
        
        # 2층부터 오차 역전파
        # (3) 오차 계산 (실체값 - 예측값)
        e = y-pred_y2
        
        # (4) 미분을 해서 기울기를 계산 (w, b가 e(= 오차)에 얼마나 영향을 주고 있는 지 분석)
        dw2 = e/w2
        db2 = e/b2
        
        # (5) 경사를 이용해서 w, b를 갱신
        # 락습률을 적용 - w,b가 너무 크게 변하는 것을 방지하기 위한 것
        w2 = w2+dw2 * lr
        b2 = b2+db2 * lr
        
        # 1층 오차역전파
        dw1 = pred_y1* dw2 /w1
        db1 = pred_y1* db2 /b1
        
        # 1층 파라미터 업데이트
        w1= w1+dw1*lr
        b1= b1+db1*lr
        
        # 중간 결과 출력
        print("반복수 : {}, 예측값 : {} ,오차 : {}".format(i, pred_y2, e))

# %%
fit_user2(1,3,100,0.01)
# Out:
# 반복수 : 0, 예측값 : [-0.4506296] ,오차 : [3.4506296]
# 반복수 : 1, 예측값 : [0.10718212] ,오차 : [2.89281788]
# 반복수 : 2, 예측값 : [0.22392488] ,오차 : [2.77607512]
# 반복수 : 3, 예측값 : [0.31288996] ,오차 : [2.68711004]
# 반복수 : 4, 예측값 : [0.38619745] ,오차 : [2.61380255]
# 반복수 : 5, 예측값 : [0.44918855] ,오차 : [2.55081145]
# 반복수 : 6, 예측값 : [0.50476627] ,오차 : [2.49523373]
# 반복수 : 7, 예측값 : [0.55470988] ,오차 : [2.44529012]
# 반복수 : 8, 예측값 : [0.60019973] ,오차 : [2.39980027]
# 반복수 : 9, 예측값 : [0.64206436] ,오차 : [2.35793564]
# 반복수 : 10, 예측값 : [0.68091057] ,오차 : [2.31908943]
# 반복수 : 11, 예측값 : [0.71719779] ,오차 : [2.28280221]
# 반복수 : 12, 예측값 : [0.75128323] ,오차 : [2.24871677]
# 반복수 : 13, 예측값 : [0.78345081] ,오차 : [2.21654919]
# 반복수 : 14, 예측값 : [0.81393035] ,오차 : [2.18606965]
# 반복수 : 15, 예측값 : [0.84291081] ,오차 : [2.15708919]
# 반복수 : 16, 예측값 : [0.87054963] ,오차 : [2.12945037]
# 반복수 : 17, 예측값 : [0.89697957] ,오차 : [2.10302043]
# 반복수 : 18, 예측값 : [0.92231368] ,오차 : [2.07768632]
# 반복수 : 19, 예측값 : [0.94664913] ,오차 : [2.05335087]
# 반복수 : 20, 예측값 : [0.97007011] ,오차 : [2.02992989]
# 반복수 : 21, 예측값 : [0.99265009] ,오차 : [2.00734991]
# 반복수 : 22, 예측값 : [1.01445363] ,오차 : [1.98554637]
# 반복수 : 23, 예측값 : [1.03553774] ,오차 : [1.96446226]
# 반복수 : 24, 예측값 : [1.05595312] ,오차 : [1.94404688]
# 반복수 : 25, 예측값 : [1.07574499] ,오차 : [1.92425501]
# 반복수 : 26, 예측값 : [1.09495394] ,오차 : [1.90504606]
# 반복수 : 27, 예측값 : [1.11361651] ,오차 : [1.88638349]
# 반복수 : 28, 예측값 : [1.13176575] ,오차 : [1.86823425]
# 반복수 : 29, 예측값 : [1.14943165] ,오차 : [1.85056835]
# 반복수 : 30, 예측값 : [1.1666415] ,오차 : [1.8333585]
# 반복수 : 31, 예측값 : [1.18342024] ,오차 : [1.81657976]
# 반복수 : 32, 예측값 : [1.19979071] ,오차 : [1.80020929]
# 반복수 : 33, 예측값 : [1.21577388] ,오차 : [1.78422612]
# 반복수 : 34, 예측값 : [1.23138906] ,오차 : [1.76861094]
# 반복수 : 35, 예측값 : [1.24665409] ,오차 : [1.75334591]
# 반복수 : 36, 예측값 : [1.26158547] ,오차 : [1.73841453]
# 반복수 : 37, 예측값 : [1.27619848] ,오차 : [1.72380152]
# 반복수 : 38, 예측값 : [1.29050734] ,오차 : [1.70949266]
# 반복수 : 39, 예측값 : [1.30452526] ,오차 : [1.69547474]
# 반복수 : 40, 예측값 : [1.31826459] ,오차 : [1.68173541]
# 반복수 : 41, 예측값 : [1.33173685] ,오차 : [1.66826315]
# 반복수 : 42, 예측값 : [1.34495281] ,오차 : [1.65504719]
# 반복수 : 43, 예측값 : [1.35792258] ,오차 : [1.64207742]
# 반복수 : 44, 예측값 : [1.37065565] ,오차 : [1.62934435]
# 반복수 : 45, 예측값 : [1.38316093] ,오차 : [1.61683907]
# 반복수 : 46, 예측값 : [1.3954468] ,오차 : [1.6045532]
# 반복수 : 47, 예측값 : [1.40752119] ,오차 : [1.59247881]
# 반복수 : 48, 예측값 : [1.41939155] ,오차 : [1.58060845]
# 반복수 : 49, 예측값 : [1.43106493] ,오차 : [1.56893507]
# 반복수 : 50, 예측값 : [1.442548] ,오차 : [1.557452]
# 반복수 : 51, 예측값 : [1.45384709] ,오차 : [1.54615291]
# 반복수 : 52, 예측값 : [1.46496817] ,오차 : [1.53503183]
# 반복수 : 53, 예측값 : [1.47591693] ,오차 : [1.52408307]
# 반복수 : 54, 예측값 : [1.48669876] ,오차 : [1.51330124]
# 반복수 : 55, 예측값 : [1.49731881] ,오차 : [1.50268119]
# 반복수 : 56, 예측값 : [1.50778195] ,오차 : [1.49221805]
# 반복수 : 57, 예측값 : [1.51809284] ,오차 : [1.48190716]
# 반복수 : 58, 예측값 : [1.52825591] ,오차 : [1.47174409]
# 반복수 : 59, 예측값 : [1.53827539] ,오차 : [1.46172461]
# 반복수 : 60, 예측값 : [1.54815534] ,오차 : [1.45184466]
# 반복수 : 61, 예측값 : [1.5578996] ,오차 : [1.4421004]
# 반복수 : 62, 예측값 : [1.56751187] ,오차 : [1.43248813]
# 반복수 : 63, 예측값 : [1.5769957] ,오차 : [1.4230043]
# 반복수 : 64, 예측값 : [1.58635445] ,오차 : [1.41364555]
# 반복수 : 65, 예측값 : [1.59559139] ,오차 : [1.40440861]
# 반복수 : 66, 예측값 : [1.60470963] ,오차 : [1.39529037]
# 반복수 : 67, 예측값 : [1.61371214] ,오차 : [1.38628786]
# 반복수 : 68, 예측값 : [1.6226018] ,오차 : [1.3773982]
# 반복수 : 69, 예측값 : [1.63138136] ,오차 : [1.36861864]
# 반복수 : 70, 예측값 : [1.64005348] ,오차 : [1.35994652]
# 반복수 : 71, 예측값 : [1.64862071] ,오차 : [1.35137929]
# 반복수 : 72, 예측값 : [1.65708549] ,오차 : [1.34291451]
# 반복수 : 73, 예측값 : [1.66545018] ,오차 : [1.33454982]
# 반복수 : 74, 예측값 : [1.67371708] ,오차 : [1.32628292]
# 반복수 : 75, 예측값 : [1.68188836] ,오차 : [1.31811164]
# 반복수 : 76, 예측값 : [1.68996615] ,오차 : [1.31003385]
# 반복수 : 77, 예측값 : [1.69795249] ,오차 : [1.30204751]
# 반복수 : 78, 예측값 : [1.70584936] ,오차 : [1.29415064]
# 반복수 : 79, 예측값 : [1.71365865] ,오차 : [1.28634135]
# 반복수 : 80, 예측값 : [1.7213822] ,오차 : [1.2786178]
# 반복수 : 81, 예측값 : [1.7290218] ,오차 : [1.2709782]
# 반복수 : 82, 예측값 : [1.73657917] ,오차 : [1.26342083]
# 반복수 : 83, 예측값 : [1.74405597] ,오차 : [1.25594403]
# 반복수 : 84, 예측값 : [1.75145382] ,오차 : [1.24854618]
# 반복수 : 85, 예측값 : [1.75877427] ,오차 : [1.24122573]
# 반복수 : 86, 예측값 : [1.76601884] ,오차 : [1.23398116]
# 반복수 : 87, 예측값 : [1.77318898] ,오차 : [1.22681102]
# 반복수 : 88, 예측값 : [1.78028613] ,오차 : [1.21971387]
# 반복수 : 89, 예측값 : [1.78731166] ,오차 : [1.21268834]
# 반복수 : 90, 예측값 : [1.79426691] ,오차 : [1.20573309]
# 반복수 : 91, 예측값 : [1.80115317] ,오차 : [1.19884683]
# 반복수 : 92, 예측값 : [1.8079717] ,오차 : [1.1920283]
# 반복수 : 93, 예측값 : [1.81472372] ,오차 : [1.18527628]
# 반복수 : 94, 예측값 : [1.82141043] ,오차 : [1.17858957]
# 반복수 : 95, 예측값 : [1.82803297] ,오차 : [1.17196703]
# 반복수 : 96, 예측값 : [1.83459247] ,오차 : [1.16540753]
# 반복수 : 97, 예측값 : [1.84109002] ,오차 : [1.15890998]
# 반복수 : 98, 예측값 : [1.84752668] ,오차 : [1.15247332]
# 반복수 : 99, 예측값 : [1.85390349] ,오차 : [1.14609651]
